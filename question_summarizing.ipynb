# %%
# !rm -r CHQ-Summ

# !git clone https://github.com/BanhKun/CHQ-Summ.git
# Out:
# rm: cannot remove 'CHQ-Summ': No such file or directory
# Cloning into 'CHQ-Summ'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 88 (delta 31), reused 22 (delta 4), pack-reused 0
# Unpacking objects: 100% (88/88), done.

# %%
# %cd /content/CHQ-Summ/
# !pip install -r requirements.txt
# !pip install transformers
# !pip install rouge
# !pip install -U transformers
# !pip install py-rouge
# !pip install --user methodtools py-rouge pyrouge nltk
# !pip install pytorch-pretrained-bert
# Out:
# /content/CHQ-Summ
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached absl_py-0.11.0-py3-none-any.whl (127 kB)
# ...
#   Using cached blis-0.7.4-cp37-cp37m-manylinux2014_x86_64.whl (9.8 MB)
# ...
#   Using cached cachetools-4.2.0-py3-none-any.whl (12 kB)
# ...
#   Using cached catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# ...
#   Using cached certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
# ...
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# ...
#   Using cached configparser-5.0.1-py3-none-any.whl (22 kB)
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#   Using cached cymem-2.0.5-cp37-cp37m-manylinux2014_x86_64.whl (35 kB)
# ...
#   Using cached Cython-0.29.21-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
# ...
#   Using cached datasets-1.2.0-py3-none-any.whl (159 kB)
# ...
#   Using cached dill-0.3.3-py2.py3-none-any.whl (81 kB)
# ...
#   Using cached filelock-3.0.12-py3-none-any.whl (7.6 kB)
# ...

# %%
# !git clone https://github.com/abachaa/MeQSum.git
# !cp /content/MeQSum/MeQSum_ACL2019_BenAbacha_Demner-Fushman.xlsx /content/CHQ-Summ/dataset/meqsum
# Out:
# fatal: destination path 'MeQSum' already exists and is not an empty directory.

# %%
# %cd /content/CHQ-Summ
# !gdown --id 17173oLqRo-ElMkYCuOX_lRxqEnacYzFk -O type_model/
# !gdown --id 1-nlrmrKUrJNeEMFy7IOknMYSQ00n_uSp -O focus_model/epochs-9/
# !gdown --id 1r0B6dfPBOeT8-PS88eWXAU0Rp-xrohpL -O focus_model/epochs-9/
# Out:
# /content/CHQ-Summ
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=17173oLqRo-ElMkYCuOX_lRxqEnacYzFk
# To: /content/CHQ-Summ/type_model/epochs-7
# 100% 440M/440M [00:01<00:00, 329MB/s]
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1-nlrmrKUrJNeEMFy7IOknMYSQ00n_uSp
# To: /content/CHQ-Summ/focus_model/epochs-9/pytorch_model.bin
# 100% 436M/436M [00:01<00:00, 333MB/s]
# ...

# %%
import transformers
# Out:
# /content
# Cloning into 'transformers'...
# remote: Enumerating objects: 100195, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 100195 (delta 51), reused 70 (delta 26), pack-reused 100060
# Receiving objects: 100% (100195/100195), 118.55 MiB | 31.49 MiB/s, done.
# Resolving deltas: 100% (73843/73843), done.
# Note: checking out 'bfa4ccf77d65d8899b01417bd9845b2e78bc0ec5'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>

# %%
import nltk
nltk.download('punkt')

# %%
# !mkdir /content/modelsmle
# !mkdir /content/modelsrl

# %%
# %cd /content/CHQ-Summ/
# !python main.py --train_mode mle --num_epochs 20 --batch_size 4 --model_dir /content/modelsmle
# Out:
# /content/CHQ-Summ
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# %cd /content/CHQ-Summ/
# !python main.py --train_mode rl --num_epochs 20 --batch_size 1 --model_dir /content/modelsrl  --trained_model_path /content/modelsmle
# Out:
# /content/CHQ-Summ
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...
